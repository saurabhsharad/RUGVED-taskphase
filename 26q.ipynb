# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir("C:\\Users\\HP\\Documents")

# %%
match = pd.read_csv("matches.csv")

# %%
match
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
os.chdir("C:\\Users\\HP\\Documents")
delivery = pd.read_csv("deliveries.csv")

# %%
delivery
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
#Q1
print(len(match[match['season']== 2008]))
# Out:
# 58

# %%
#q2
print(match['city'].value_counts().idxmax())
print(match['city'].value_counts().idxmin())
# Out:
# Mumbai
# Bloemfontein

# %%
#Q3
print(match['city'].value_counts())
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
#q4 
print(match['toss_winner'].value_counts().idxmax())
print(match['toss_winner'].value_counts().idxmin())
# Out:
# Mumbai Indians
# Rising Pune Supergiant

# %%
#Q5toss decision
print(match.groupby("toss_winner")["toss_decision"].value_counts().to_string(name=False))
# Out:
# toss_winner                  toss_decision
# Chennai Super Kings          bat              48
#                              field            41
# Deccan Chargers              bat              24
#                              field            19
# Delhi Capitals               field             8
#                              bat               2
# Delhi Daredevils             field            51
#                              bat              29
# Gujarat Lions                field            14
#                              bat               1
# Kings XI Punjab              field            55
#                              bat              26
# Kochi Tuskers Kerala         field             5
#                              bat               3
# Kolkata Knight Riders        field            62
#                              bat              30
# Mumbai Indians               field            54
#                              bat              44
# ...

# %%
#q6
print(len(match[match['result']=='tie']))
print(len(match[match['result']=='normal']))
# Out:
# 9
# 743

# %%
#Q7

print(match.loc[match["result"] == "tie", ["team1","team2"]].to_string(index = False))
# Out:
#                       team1                       team2
#               Gujarat Lions              Mumbai Indians
#            Rajasthan Royals       Kolkata Knight Riders
#             Kings XI Punjab         Chennai Super Kings
# Royal Challengers Bangalore         Sunrisers Hyderabad
#            Delhi Daredevils Royal Challengers Bangalore
#            Rajasthan Royals       Kolkata Knight Riders
#            Rajasthan Royals             Kings XI Punjab
#       Kolkata Knight Riders              Delhi Capitals
#              Mumbai Indians         Sunrisers Hyderabad

# %%
#Q8
match['winner'][match['win_by_runs'].idxmax()]
# Out:
# 'Mumbai Indians'

# %%
#Q9
match['winner'][match['win_by_runs'].idxmin()]
# Out:
# 'Rising Pune Supergiant'

# %%
#q10
value_counts = match['player_of_match'].value_counts()
print(value_counts[value_counts > 3])
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# SK Warne           4
# CA Lynn            4
# SS Iyer            4
# ML Hayden          4
# KH Pandya          4
# Name: count, Length: 65, dtype: int64

# %%
#Q11
print(match['player_of_match'].value_counts().idxmax())
# Out:
# CH Gayle

# %%
#Q12
match['venue'][match['win_by_runs'].idxmax()]
# Out:
# 'Feroz Shah Kotla'

# %%
#Q13
match['venue'][match['win_by_runs'].idxmin()]
# Out:
# 'Maharashtra Cricket Association Stadium'

# %%
#q14
umpires = pd.concat([match["umpire1"], match["umpire2"], match["umpire3"]])
print(umpires.value_counts().idxmax())
# Out:
# S Ravi

# %%
#q15
print(match['season'].value_counts())
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
#q17
print(match['toss_winner'].value_counts())
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
#q19

dismissal=delivery['dismissal_kind'].value_counts()

x = np.arange(len(dismissal))

plt.bar(x,dismissal.values, 0.9, color = "y")
plt.xticks(x, dismissal.index, rotation = 45, fontsize = 10 )
plt.show()

# %%
#q20

batsman_runs = delivery.groupby("batsman")["total_runs"].sum()
batsman_runs = batsman_runs.sort_values(ascending=False).head(10)
x = np.arange(len(batsman_runs))
plt.title('Top 10 Run Scorer')
plt.bar(x, batsman_runs.values, 0.6, color = "y")
plt.xticks(x, batsman_runs.index, rotation = 45)
plt.show()

# %%
#q21

x = np.arange(10)
top_mom= match["player_of_match"].value_counts().head(10)

plt.title('Top 10 MOM')
plt.bar(x, top_mom.values, 0.6 ,color = "blue")
plt.xticks(x, top_mom.index, rotation = 70)
plt.show()

# %%
#q22

total = pd.concat([match["team1"], match["team2"]])
x = np.arange(len(set(total)))

plt.bar(x, total.value_counts().sort_index().values, 0.8, color = "b")
plt.xticks(x, total.value_counts().sort_index().index, rotation = 90)
plt.show()

# %%
#Q23

matches_played = pd.concat([match["team1"], match["team2"]]).value_counts().sort_index()
match_wins = match["winner"].value_counts().sort_index()
match_win_rate = (match_wins.to_numpy() / matches_played.to_numpy())*100

x = np.arange(len(pd.concat([match["team1"],match["team2"]]).unique()))
w = 0.3

plt.bar(x-w, matches_played, w, color = "y")
plt.bar(x, match_wins, w, color = "r")
plt.bar(x+w , match_win_rate, w, color = "b")
plt.xticks(x,matches_played.index, rotation = 90)
plt.legend(["matches played", "matches won", "match win rate"])
plt.show()

# %%
#q24

win_ = match["winner"].value_counts()

x = np.arange(len(set(match["team1"])))

plt.bar(x, win_, 0.6, color = "y")
plt.xticks(x, win_.index, rotation = 90)
plt.show()

# %%
#q25

wins_ = match["winner"].value_counts().sort_index()
win_rate = (wins_.to_numpy() / matches_played.to_numpy())*100
plt.bar(x, win_rate/100, 0.8, color = "blue")
plt.xticks(x, wins_.index, rotation = 70)
plt.show()
